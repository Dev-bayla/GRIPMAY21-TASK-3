# %% [markdown]
# # TASK 3: Exploratory Data Analysis on SampleSuperstore,
# # Find out the weak areas where you can work to make more profit.
# # Dev Bayla

# %% [markdown]
# collecting necessary libraries

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the Dataset
#
# The data is about transaction of products of an chain of super store in the United States
#
# my strategy is to do univariate or bivariate analysis on the columns.

# %%
raw_data = pd.read_csv(r'C:\Users\Mohan\Downloads\SampleSuperstore.csv')

# %%
raw_data
# Out:
#            Ship Mode      Segment        Country             City  \
# 0       Second Class     Consumer  United States        Henderson
# 1       Second Class     Consumer  United States        Henderson
# 2       Second Class    Corporate  United States      Los Angeles
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 4     Standard Class     Consumer  United States  Fort Lauderdale
# 5     Standard Class     Consumer  United States      Los Angeles
# 6     Standard Class     Consumer  United States      Los Angeles
# 7     Standard Class     Consumer  United States      Los Angeles
# 8     Standard Class     Consumer  United States      Los Angeles
# 9     Standard Class     Consumer  United States      Los Angeles
# 10    Standard Class     Consumer  United States      Los Angeles
# 11    Standard Class     Consumer  United States      Los Angeles
# 12    Standard Class     Consumer  United States          Concord
# ...

# %%
raw_data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
raw_data.shape
# Out:
# (9994, 13)

# %%
raw_data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
raw_data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# since Country is a constant it could be removed

# %%
raw_data.drop(['Country'],axis=1,inplace=True)

# %%
sns.barplot(x='Ship Mode',y='Profit',data=raw_data)

# %% [markdown]
# Here we can see that among 915 transactions in NYC 868 have yielded a profit.
# we can apply this to every city or by a little change in the code ,see the losses.

# %%
a=raw_data['City']
b=raw_data['Profit']>0
c=a[b]
c.value_counts()
# Out:
# New York City        868
# Los Angeles          705
# San Francisco        482
# Seattle              406
# Philadelphia         283
# Houston              190
# Columbus             171
# San Diego            158
# Chicago              157
# Springfield          133
# Detroit              115
# Richmond              90
# Dallas                84
# Jacksonville          84
# Newark                82
# Jackson               80
# Columbia              74
# Long Beach            56
# Rochester             51
# Henderson             50
# Louisville            49
# Milwaukee             45
# Arlington             43
# Lawrence              42
# Baltimore             42
# San Jose              40
# Lakewood              40
# Atlanta               39
# Charlotte             37
# Fairfield             36
#                     ...
# Cheyenne               1
# Orland Park            1
# Manhattan              1
# Vacaville              1
# Buffalo Grove          1
# Mansfield              1
# ...

# %%
a=(raw_data['City']=='New York City')
a.value_counts()
# Out:
# False    9079
# True      915
# Name: City, dtype: int64

# %% [markdown]
# here i wanted to check the region column,its a country based variable

# %%
raw_data['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
a=raw_data["State"]
b=(raw_data['Region']=='Central')
c=a[b]
c.value_counts()
# Out:
# Texas           985
# Illinois        492
# Michigan        255
# Indiana         149
# Wisconsin       110
# Minnesota        89
# Oklahoma         66
# Missouri         66
# Nebraska         38
# Iowa             30
# Kansas           24
# South Dakota     12
# North Dakota      7
# Name: State, dtype: int64

# %%
sns.barplot(raw_data['Segment'],raw_data['Sales'])
plt.show()

# %%
sns.barplot(raw_data['Segment'],raw_data['Profit'])
plt.show()

# %%
raw_data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
X = raw_data.corr()
sns.heatmap(X,annot=True)

# %%
plt.scatter(x='Sales',y='Profit',data=raw_data)
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
plt.scatter(x='Discount',y='Profit',data=raw_data)
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %%
plt.scatter(x='Quantity',y='Profit',data=raw_data)
plt.show()

# %%
y=(raw_data['Quantity']==13)
x=raw_data['Category']
z=x[y]
a=(raw_data['Profit']>=0)
sns.countplot(z[a])

# %% [markdown]
# if 5 items are bought then based on category profit count will be

# %%
y=(raw_data['Quantity']==5)
x=raw_data['Category']
z=x[y]
a=(raw_data['Profit']>=0)
sns.countplot(z[a])

# %% [markdown]
# if 5 items are bought then based on category profit count will be

# %%
y=(raw_data['Quantity']==5)
x=raw_data['Category']
z=x[y]
a=(raw_data['Profit']<=0)
sns.countplot(z[a])

# %%
sns.barplot(raw_data['Category'],raw_data['Profit'])
plt.show()

# %%
sns.barplot(raw_data['Category'],raw_data['Sales'])
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(raw_data['Sub-Category'],raw_data['Profit'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(raw_data['Sub-Category'],raw_data['Sales'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Among all other information i have 3 key points which i believe deserve focus

# %% [markdown]
# 1) Discount should not be more than 0.3
#
# 2) Furniture Sector is suffering losses
#
# 3) Tables,book cases and supplies are suffering losses
